# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, ShuffleSplit
import pickle

import sys
sys.path.append('../okko')

from data_preprocess import load_and_preprocess_data

# %%
(train_x, train_y, test_x) = load_and_preprocess_data()

# %% [markdown]
# ## Random Forest

# %%
dropped_features = ['apin_toluene', 'decane_toluene', 'C=C-C=O in non-aromatic ring', 'toluene',
    'NumOfN', 'nitroester', 'nitrate', 'NumOfAtoms', 'MW']
train_x = train_x.loc[:, ~train_x.columns.isin(dropped_features)]

# %%
try:
    with open('../pickles/rf_random_search_tuning_results.pickle', 'rb') as handle:
        rf_random_search_results = pickle.load(handle)
except:
    params = {
        'n_estimators': [int(x) for x in np.linspace(start=50, stop=1000, num=10)],  # Extended range
        'max_features': ['auto', 'sqrt', 'log2', 0.5, 0.8],  # Additional options
        'max_depth': [None] + [int(x) for x in np.linspace(10, 250, num=25)],  # Extended depth range
        'min_samples_split': [2, 5, 10, 15, 20],  # More values to explore
        'min_samples_leaf': [1, 2, 4, 8, 10],  # Additional values
        'bootstrap': [True, False]  # Bootstrap options
    }
    

    r_search = RandomizedSearchCV(RandomForestRegressor(n_jobs=-1), params, n_iter=500, scoring=['r2', 'neg_mean_squared_error'], verbose=3, refit=False)
    r_search.fit(train_x, train_y)
    rf_random_search_results = r_search.cv_results_

rf_random_search_tuning_results = pd.DataFrame({
    'R2': rf_random_search_results['mean_test_r2'],
    'MSE': rf_random_search_results['mean_test_neg_mean_squared_error'],
    'n_estimators': rf_random_search_results['param_n_estimators'],
    'max_features': rf_random_search_results['param_max_features'],
    'max_depth': rf_random_search_results['param_max_depth'],
    'min_samples_split': rf_random_search_results['param_min_samples_split'],
    'min_samples_leaf': rf_random_search_results['param_min_samples_leaf'],
    'bootstrap' : rf_random_search_results['param_bootstrap'],
    'rank R2': rf_random_search_results['rank_test_r2'],
    'rank MSE': rf_random_search_results['rank_test_neg_mean_squared_error'],
})
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [CV 1/5] END bootstrap=False, max_depth=130, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=683; neg_mean_squared_error: (test=-2.672) r2: (test=0.730) total time=   8.4s
# [CV 2/5] END bootstrap=False, max_depth=130, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=683; neg_mean_squared_error: (test=-2.738) r2: (test=0.719) total time=   8.2s
# [CV 3/5] END bootstrap=False, max_depth=130, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=683; neg_mean_squared_error: (test=-2.754) r2: (test=0.718) total time=   8.1s
# [CV 4/5] END bootstrap=False, max_depth=130, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=683; neg_mean_squared_error: (test=-2.804) r2: (test=0.714) total time=   8.2s
# [CV 5/5] END bootstrap=False, max_depth=130, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=683; neg_mean_squared_error: (test=-2.623) r2: (test=0.726) total time=   8.3s
# [CV 1/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=472; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=472; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=472; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=472; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=472; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=20, n_estimators=577; neg_mean_squared_error: (test=-2.606) r2: (test=0.737) total time=   2.2s
# [CV 2/5] END bootstrap=True, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=20, n_estimators=577; neg_mean_squared_error: (test=-2.687) r2: (test=0.724) total time=   2.4s
# [CV 3/5] END bootstrap=True, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=20, n_estimators=577; neg_mean_squared_error: (test=-2.663) r2: (test=0.727) total time=   2.2s
# [CV 4/5] END bootstrap=True, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=20, n_estimators=577; neg_mean_squared_error: (test=-2.737) r2: (test=0.721) total time=   2.2s
# [CV 5/5] END bootstrap=True, max_depth=230, max_features=log2, min_samples_leaf=2, min_samples_split=20, n_estimators=577; neg_mean_squared_error: (test=-2.527) r2: (test=0.736) total time=   2.3s
# [CV 1/5] END bootstrap=False, max_depth=130, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=894; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=130, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=894; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=130, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=894; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=130, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=894; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=130, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=894; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=80, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=366; neg_mean_squared_error: (test=-2.568) r2: (test=0.740) total time=   2.0s
# [CV 2/5] END bootstrap=False, max_depth=80, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=366; neg_mean_squared_error: (test=-2.651) r2: (test=0.728) total time=   2.1s
# [CV 3/5] END bootstrap=False, max_depth=80, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=366; neg_mean_squared_error: (test=-2.639) r2: (test=0.730) total time=   1.8s
# [CV 4/5] END bootstrap=False, max_depth=80, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=366; neg_mean_squared_error: (test=-2.700) r2: (test=0.724) total time=   1.9s
# [CV 5/5] END bootstrap=False, max_depth=80, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=366; neg_mean_squared_error: (test=-2.514) r2: (test=0.737) total time=   1.9s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=50; neg_mean_squared_error: (test=-2.626) r2: (test=0.734) total time=   0.5s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=50; neg_mean_squared_error: (test=-2.689) r2: (test=0.724) total time=   0.5s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=50; neg_mean_squared_error: (test=-2.682) r2: (test=0.726) total time=   0.6s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=50; neg_mean_squared_error: (test=-2.745) r2: (test=0.720) total time=   0.5s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=50; neg_mean_squared_error: (test=-2.562) r2: (test=0.732) total time=   0.8s
# [CV 1/5] END bootstrap=False, max_depth=210, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.708) r2: (test=0.726) total time=   7.5s
# [CV 2/5] END bootstrap=False, max_depth=210, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.759) r2: (test=0.716) total time=   7.1s
# [CV 3/5] END bootstrap=False, max_depth=210, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.802) r2: (test=0.713) total time=   6.7s
# [CV 4/5] END bootstrap=False, max_depth=210, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.842) r2: (test=0.710) total time=   6.9s
# [CV 5/5] END bootstrap=False, max_depth=210, max_features=0.5, min_samples_leaf=2, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.669) r2: (test=0.721) total time=   6.8s
# [CV 1/5] END bootstrap=False, max_depth=180, max_features=0.8, min_samples_leaf=10, min_samples_split=15, n_estimators=155; neg_mean_squared_error: (test=-2.677) r2: (test=0.729) total time=   1.8s
# [CV 2/5] END bootstrap=False, max_depth=180, max_features=0.8, min_samples_leaf=10, min_samples_split=15, n_estimators=155; neg_mean_squared_error: (test=-2.737) r2: (test=0.719) total time=   1.8s
# [CV 3/5] END bootstrap=False, max_depth=180, max_features=0.8, min_samples_leaf=10, min_samples_split=15, n_estimators=155; neg_mean_squared_error: (test=-2.749) r2: (test=0.719) total time=   1.8s
# [CV 4/5] END bootstrap=False, max_depth=180, max_features=0.8, min_samples_leaf=10, min_samples_split=15, n_estimators=155; neg_mean_squared_error: (test=-2.804) r2: (test=0.714) total time=   1.9s
# [CV 5/5] END bootstrap=False, max_depth=180, max_features=0.8, min_samples_leaf=10, min_samples_split=15, n_estimators=155; neg_mean_squared_error: (test=-2.620) r2: (test=0.726) total time=   1.8s
# [CV 1/5] END bootstrap=False, max_depth=150, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=150, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=150, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=150, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=150, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=-2.554) r2: (test=0.742) total time=   4.4s
# [CV 2/5] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=-2.638) r2: (test=0.729) total time=   4.4s
# [CV 3/5] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=-2.616) r2: (test=0.732) total time=   4.5s
# [CV 4/5] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=-2.691) r2: (test=0.725) total time=   4.4s
# [CV 5/5] END bootstrap=False, max_depth=60, max_features=sqrt, min_samples_leaf=1, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=-2.483) r2: (test=0.740) total time=   4.6s
# [CV 1/5] END bootstrap=True, max_depth=240, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=261; neg_mean_squared_error: (test=-2.607) r2: (test=0.736) total time=   2.3s
# [CV 2/5] END bootstrap=True, max_depth=240, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=261; neg_mean_squared_error: (test=-2.684) r2: (test=0.724) total time=   2.3s
# [CV 3/5] END bootstrap=True, max_depth=240, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=261; neg_mean_squared_error: (test=-2.669) r2: (test=0.727) total time=   2.3s
# [CV 4/5] END bootstrap=True, max_depth=240, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=261; neg_mean_squared_error: (test=-2.737) r2: (test=0.721) total time=   2.3s
# [CV 5/5] END bootstrap=True, max_depth=240, max_features=0.8, min_samples_leaf=10, min_samples_split=2, n_estimators=261; neg_mean_squared_error: (test=-2.553) r2: (test=0.733) total time=   2.3s
# [CV 1/5] END bootstrap=False, max_depth=220, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; neg_mean_squared_error: (test=-2.767) r2: (test=0.720) total time=  15.4s
# [CV 2/5] END bootstrap=False, max_depth=220, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; neg_mean_squared_error: (test=-2.823) r2: (test=0.710) total time=  15.4s
# [CV 3/5] END bootstrap=False, max_depth=220, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; neg_mean_squared_error: (test=-2.841) r2: (test=0.709) total time=  15.5s
# [CV 4/5] END bootstrap=False, max_depth=220, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; neg_mean_squared_error: (test=-2.898) r2: (test=0.704) total time=  15.4s
# [CV 5/5] END bootstrap=False, max_depth=220, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=1000; neg_mean_squared_error: (test=-2.738) r2: (test=0.714) total time=  17.2s
# [CV 1/5] END bootstrap=True, max_depth=150, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=1000; neg_mean_squared_error: (test=-2.594) r2: (test=0.738) total time=   8.9s
# [CV 2/5] END bootstrap=True, max_depth=150, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=1000; neg_mean_squared_error: (test=-2.675) r2: (test=0.725) total time=   9.1s
# [CV 3/5] END bootstrap=True, max_depth=150, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=1000; neg_mean_squared_error: (test=-2.653) r2: (test=0.728) total time=   9.0s
# [CV 4/5] END bootstrap=True, max_depth=150, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=1000; neg_mean_squared_error: (test=-2.723) r2: (test=0.722) total time=   9.0s
# [CV 5/5] END bootstrap=True, max_depth=150, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=1000; neg_mean_squared_error: (test=-2.530) r2: (test=0.735) total time=   9.2s
# [CV 1/5] END bootstrap=False, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=155; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=155; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=155; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=155; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=230, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=155; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; neg_mean_squared_error: (test=-2.542) r2: (test=0.743) total time=   5.8s
# [CV 2/5] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; neg_mean_squared_error: (test=-2.631) r2: (test=0.730) total time=   5.9s
# [CV 3/5] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; neg_mean_squared_error: (test=-2.619) r2: (test=0.732) total time=   6.0s
# [CV 4/5] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; neg_mean_squared_error: (test=-2.695) r2: (test=0.725) total time=   6.6s
# [CV 5/5] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; neg_mean_squared_error: (test=-2.492) r2: (test=0.739) total time=   6.7s
# [CV 1/5] END bootstrap=False, max_depth=230, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.667) r2: (test=0.730) total time=   2.5s
# [CV 2/5] END bootstrap=False, max_depth=230, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.739) r2: (test=0.718) total time=   2.5s
# [CV 3/5] END bootstrap=False, max_depth=230, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.723) r2: (test=0.721) total time=   2.5s
# [CV 4/5] END bootstrap=False, max_depth=230, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.778) r2: (test=0.716) total time=   2.4s
# [CV 5/5] END bootstrap=False, max_depth=230, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.581) r2: (test=0.730) total time=   2.5s
# [CV 1/5] END bootstrap=True, max_depth=170, max_features=0.8, min_samples_leaf=2, min_samples_split=15, n_estimators=50; neg_mean_squared_error: (test=-2.598) r2: (test=0.737) total time=   0.6s
# [CV 2/5] END bootstrap=True, max_depth=170, max_features=0.8, min_samples_leaf=2, min_samples_split=15, n_estimators=50; neg_mean_squared_error: (test=-2.673) r2: (test=0.725) total time=   0.6s
# [CV 3/5] END bootstrap=True, max_depth=170, max_features=0.8, min_samples_leaf=2, min_samples_split=15, n_estimators=50; neg_mean_squared_error: (test=-2.630) r2: (test=0.731) total time=   0.6s
# [CV 4/5] END bootstrap=True, max_depth=170, max_features=0.8, min_samples_leaf=2, min_samples_split=15, n_estimators=50; neg_mean_squared_error: (test=-2.751) r2: (test=0.719) total time=   0.6s
# [CV 5/5] END bootstrap=True, max_depth=170, max_features=0.8, min_samples_leaf=2, min_samples_split=15, n_estimators=50; neg_mean_squared_error: (test=-2.537) r2: (test=0.735) total time=   0.6s
# [CV 1/5] END bootstrap=True, max_depth=90, max_features=0.8, min_samples_leaf=1, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.565) r2: (test=0.741) total time=   1.7s
# [CV 2/5] END bootstrap=True, max_depth=90, max_features=0.8, min_samples_leaf=1, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.642) r2: (test=0.728) total time=   1.6s
# [CV 3/5] END bootstrap=True, max_depth=90, max_features=0.8, min_samples_leaf=1, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.643) r2: (test=0.730) total time=   1.6s
# [CV 4/5] END bootstrap=True, max_depth=90, max_features=0.8, min_samples_leaf=1, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.714) r2: (test=0.723) total time=   1.6s
# [CV 5/5] END bootstrap=True, max_depth=90, max_features=0.8, min_samples_leaf=1, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.505) r2: (test=0.738) total time=   1.6s
# [CV 1/5] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.552) r2: (test=0.742) total time=   2.9s
# [CV 2/5] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.635) r2: (test=0.729) total time=   2.8s
# [CV 3/5] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.621) r2: (test=0.732) total time=   2.8s
# [CV 4/5] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.687) r2: (test=0.726) total time=   2.8s
# [CV 5/5] END bootstrap=True, max_depth=110, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=577; neg_mean_squared_error: (test=-2.497) r2: (test=0.739) total time=   2.6s
# [CV 1/5] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=155; neg_mean_squared_error: (test=-2.647) r2: (test=0.732) total time=   0.7s
# [CV 2/5] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=155; neg_mean_squared_error: (test=-2.707) r2: (test=0.722) total time=   0.7s
# [CV 3/5] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=155; neg_mean_squared_error: (test=-2.699) r2: (test=0.724) total time=   0.7s
# [CV 4/5] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=155; neg_mean_squared_error: (test=-2.754) r2: (test=0.719) total time=   0.6s
# [CV 5/5] END bootstrap=False, max_depth=100, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=155; neg_mean_squared_error: (test=-2.566) r2: (test=0.732) total time=   0.6s
# [CV 1/5] END bootstrap=False, max_depth=220, max_features=auto, min_samples_leaf=8, min_samples_split=15, n_estimators=577; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=220, max_features=auto, min_samples_leaf=8, min_samples_split=15, n_estimators=577; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=220, max_features=auto, min_samples_leaf=8, min_samples_split=15, n_estimators=577; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=220, max_features=auto, min_samples_leaf=8, min_samples_split=15, n_estimators=577; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=220, max_features=auto, min_samples_leaf=8, min_samples_split=15, n_estimators=577; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=20, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=210, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=261; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=210, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=261; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=210, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=261; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=210, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=261; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=210, max_features=auto, min_samples_leaf=10, min_samples_split=20, n_estimators=261; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=150, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=366; neg_mean_squared_error: (test=-2.558) r2: (test=0.741) total time=   2.3s
# [CV 2/5] END bootstrap=True, max_depth=150, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=366; neg_mean_squared_error: (test=-2.636) r2: (test=0.729) total time=   2.4s
# [CV 3/5] END bootstrap=True, max_depth=150, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=366; neg_mean_squared_error: (test=-2.613) r2: (test=0.733) total time=   2.4s
# [CV 4/5] END bootstrap=True, max_depth=150, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=366; neg_mean_squared_error: (test=-2.687) r2: (test=0.726) total time=   2.6s
# [CV 5/5] END bootstrap=True, max_depth=150, max_features=0.5, min_samples_leaf=4, min_samples_split=10, n_estimators=366; neg_mean_squared_error: (test=-2.499) r2: (test=0.739) total time=   2.8s
# [CV 1/5] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.616) r2: (test=0.735) total time=   0.7s
# [CV 2/5] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.697) r2: (test=0.723) total time=   0.6s
# [CV 3/5] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.669) r2: (test=0.727) total time=   0.7s
# [CV 4/5] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.739) r2: (test=0.720) total time=   0.7s
# [CV 5/5] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.524) r2: (test=0.736) total time=   0.7s
# [CV 1/5] END bootstrap=True, max_depth=250, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.618) r2: (test=0.735) total time=   0.7s
# [CV 2/5] END bootstrap=True, max_depth=250, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.694) r2: (test=0.723) total time=   0.7s
# [CV 3/5] END bootstrap=True, max_depth=250, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.661) r2: (test=0.728) total time=   0.7s
# [CV 4/5] END bootstrap=True, max_depth=250, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.733) r2: (test=0.721) total time=   0.8s
# [CV 5/5] END bootstrap=True, max_depth=250, max_features=sqrt, min_samples_leaf=2, min_samples_split=20, n_estimators=155; neg_mean_squared_error: (test=-2.543) r2: (test=0.734) total time=   0.7s
# [CV 1/5] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=8, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.596) r2: (test=0.737) total time=   1.0s
# [CV 2/5] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=8, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.670) r2: (test=0.726) total time=   1.1s
# [CV 3/5] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=8, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.651) r2: (test=0.729) total time=   1.1s
# [CV 4/5] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=8, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.720) r2: (test=0.722) total time=   1.0s
# [CV 5/5] END bootstrap=True, max_depth=None, max_features=0.5, min_samples_leaf=8, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.524) r2: (test=0.736) total time=   1.0s
# [CV 1/5] END bootstrap=False, max_depth=180, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=261; neg_mean_squared_error: (test=-2.665) r2: (test=0.730) total time=   1.1s
# [CV 2/5] END bootstrap=False, max_depth=180, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=261; neg_mean_squared_error: (test=-2.742) r2: (test=0.718) total time=   1.1s
# [CV 3/5] END bootstrap=False, max_depth=180, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=261; neg_mean_squared_error: (test=-2.725) r2: (test=0.721) total time=   1.1s
# [CV 4/5] END bootstrap=False, max_depth=180, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=261; neg_mean_squared_error: (test=-2.783) r2: (test=0.716) total time=   1.3s
# [CV 5/5] END bootstrap=False, max_depth=180, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=261; neg_mean_squared_error: (test=-2.590) r2: (test=0.729) total time=   1.3s
# [CV 1/5] END bootstrap=False, max_depth=250, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1000; neg_mean_squared_error: (test=-2.639) r2: (test=0.733) total time=   5.3s
# [CV 2/5] END bootstrap=False, max_depth=250, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1000; neg_mean_squared_error: (test=-2.709) r2: (test=0.722) total time=   5.0s
# [CV 3/5] END bootstrap=False, max_depth=250, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1000; neg_mean_squared_error: (test=-2.689) r2: (test=0.725) total time=   5.0s
# [CV 4/5] END bootstrap=False, max_depth=250, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1000; neg_mean_squared_error: (test=-2.750) r2: (test=0.719) total time=   4.4s
# [CV 5/5] END bootstrap=False, max_depth=250, max_features=sqrt, min_samples_leaf=8, min_samples_split=2, n_estimators=1000; neg_mean_squared_error: (test=-2.554) r2: (test=0.733) total time=   5.0s
# [CV 1/5] END bootstrap=False, max_depth=160, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=788; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=160, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=788; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=160, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=788; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=160, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=788; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=160, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=788; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 1/5] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.539) r2: (test=0.743) total time=   0.8s
# [CV 2/5] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.645) r2: (test=0.728) total time=   1.1s
# [CV 3/5] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.642) r2: (test=0.730) total time=   0.8s
# [CV 4/5] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.713) r2: (test=0.723) total time=   0.8s
# [CV 5/5] END bootstrap=True, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.524) r2: (test=0.736) total time=   0.8s
# [CV 1/5] END bootstrap=True, max_depth=30, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.598) r2: (test=0.737) total time=   1.6s
# [CV 2/5] END bootstrap=True, max_depth=30, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.664) r2: (test=0.726) total time=   1.7s
# [CV 3/5] END bootstrap=True, max_depth=30, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.663) r2: (test=0.728) total time=   1.6s
# [CV 4/5] END bootstrap=True, max_depth=30, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.715) r2: (test=0.723) total time=   1.7s
# [CV 5/5] END bootstrap=True, max_depth=30, max_features=0.8, min_samples_leaf=4, min_samples_split=5, n_estimators=155; neg_mean_squared_error: (test=-2.536) r2: (test=0.735) total time=   1.5s
# [CV 1/5] END bootstrap=False, max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=-2.671) r2: (test=0.730) total time=   2.5s
# [CV 2/5] END bootstrap=False, max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=-2.736) r2: (test=0.719) total time=   2.6s
# [CV 3/5] END bootstrap=False, max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=-2.720) r2: (test=0.722) total time=   2.7s
# [CV 4/5] END bootstrap=False, max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=-2.778) r2: (test=0.716) total time=   3.0s
# [CV 5/5] END bootstrap=False, max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=-2.582) r2: (test=0.730) total time=   2.9s
# [CV 1/5] END bootstrap=False, max_depth=250, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=261; neg_mean_squared_error: (test=-2.546) r2: (test=0.743) total time=   1.4s
# [CV 2/5] END bootstrap=False, max_depth=250, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=261; neg_mean_squared_error: (test=-2.634) r2: (test=0.729) total time=   1.4s
# [CV 3/5] END bootstrap=False, max_depth=250, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=261; neg_mean_squared_error: (test=-2.608) r2: (test=0.733) total time=   1.5s
# [CV 4/5] END bootstrap=False, max_depth=250, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=261; neg_mean_squared_error: (test=-2.692) r2: (test=0.725) total time=   1.4s
# [CV 5/5] END bootstrap=False, max_depth=250, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=261; neg_mean_squared_error: (test=-2.486) r2: (test=0.740) total time=   1.4s
# [CV 1/5] END bootstrap=False, max_depth=230, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=-2.681) r2: (test=0.729) total time=   8.4s
# [CV 2/5] END bootstrap=False, max_depth=230, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=-2.743) r2: (test=0.718) total time=   8.1s
# [CV 3/5] END bootstrap=False, max_depth=230, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=-2.766) r2: (test=0.717) total time=   8.1s
# [CV 4/5] END bootstrap=False, max_depth=230, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=-2.815) r2: (test=0.713) total time=   8.3s
# [CV 5/5] END bootstrap=False, max_depth=230, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=683; neg_mean_squared_error: (test=-2.639) r2: (test=0.724) total time=   9.2s
# [CV 1/5] END bootstrap=False, max_depth=130, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=-2.645) r2: (test=0.733) total time=   4.3s
# [CV 2/5] END bootstrap=False, max_depth=130, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=-2.715) r2: (test=0.721) total time=   4.3s
# [CV 3/5] END bootstrap=False, max_depth=130, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=-2.690) r2: (test=0.725) total time=   3.7s
# [CV 4/5] END bootstrap=False, max_depth=130, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=-2.756) r2: (test=0.719) total time=   4.0s
# [CV 5/5] END bootstrap=False, max_depth=130, max_features=sqrt, min_samples_leaf=8, min_samples_split=20, n_estimators=1000; neg_mean_squared_error: (test=-2.563) r2: (test=0.732) total time=   3.7s
# [CV 1/5] END bootstrap=True, max_depth=90, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=894; neg_mean_squared_error: (test=-2.592) r2: (test=0.738) total time=   8.4s
# [CV 2/5] END bootstrap=True, max_depth=90, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=894; neg_mean_squared_error: (test=-2.672) r2: (test=0.725) total time=   8.1s
# [CV 3/5] END bootstrap=True, max_depth=90, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=894; neg_mean_squared_error: (test=-2.653) r2: (test=0.728) total time=   8.2s
# [CV 4/5] END bootstrap=True, max_depth=90, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=894; neg_mean_squared_error: (test=-2.724) r2: (test=0.722) total time=   8.2s
# [CV 5/5] END bootstrap=True, max_depth=90, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=894; neg_mean_squared_error: (test=-2.531) r2: (test=0.735) total time=   7.6s
# [CV 1/5] END bootstrap=False, max_depth=110, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=366; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 2/5] END bootstrap=False, max_depth=110, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=366; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 3/5] END bootstrap=False, max_depth=110, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=366; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 4/5] END bootstrap=False, max_depth=110, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=366; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 5/5] END bootstrap=False, max_depth=110, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=366; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=240, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=577; neg_mean_squared_error: (test=-2.618) r2: (test=0.735) total time=   3.7s
# [CV 2/5] END bootstrap=False, max_depth=240, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=577; neg_mean_squared_error: (test=-2.710) r2: (test=0.721) total time=   3.7s
# [CV 3/5] END bootstrap=False, max_depth=240, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=577; neg_mean_squared_error: (test=-2.703) r2: (test=0.723) total time=   4.0s
# [CV 4/5] END bootstrap=False, max_depth=240, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=577; neg_mean_squared_error: (test=-2.775) r2: (test=0.717) total time=   4.6s
# [CV 5/5] END bootstrap=False, max_depth=240, max_features=log2, min_samples_leaf=1, min_samples_split=5, n_estimators=577; neg_mean_squared_error: (test=-2.572) r2: (test=0.731) total time=   4.6s
# [CV 1/5] END bootstrap=True, max_depth=240, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; neg_mean_squared_error: (test=-2.563) r2: (test=0.741) total time=   4.4s
# [CV 2/5] END bootstrap=True, max_depth=240, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; neg_mean_squared_error: (test=-2.651) r2: (test=0.728) total time=   4.9s
# [CV 3/5] END bootstrap=True, max_depth=240, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; neg_mean_squared_error: (test=-2.625) r2: (test=0.731) total time=   5.0s
# [CV 4/5] END bootstrap=True, max_depth=240, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; neg_mean_squared_error: (test=-2.702) r2: (test=0.724) total time=   5.0s
# [CV 5/5] END bootstrap=True, max_depth=240, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; neg_mean_squared_error: (test=-2.488) r2: (test=0.740) total time=   5.2s
# [CV 1/5] END bootstrap=True, max_depth=250, max_features=0.5, min_samples_leaf=8, min_samples_split=2, n_estimators=472; neg_mean_squared_error: (test=-2.588) r2: (test=0.738) total time=   3.6s
# [CV 2/5] END bootstrap=True, max_depth=250, max_features=0.5, min_samples_leaf=8, min_samples_split=2, n_estimators=472; neg_mean_squared_error: (test=-2.666) r2: (test=0.726) total time=   3.4s
# [CV 3/5] END bootstrap=True, max_depth=250, max_features=0.5, min_samples_leaf=8, min_samples_split=2, n_estimators=472; neg_mean_squared_error: (test=-2.644) r2: (test=0.729) total time=   3.5s
# [CV 4/5] END bootstrap=True, max_depth=250, max_features=0.5, min_samples_leaf=8, min_samples_split=2, n_estimators=472; neg_mean_squared_error: (test=-2.712) r2: (test=0.723) total time=   3.5s
# [CV 5/5] END bootstrap=True, max_depth=250, max_features=0.5, min_samples_leaf=8, min_samples_split=2, n_estimators=472; neg_mean_squared_error: (test=-2.521) r2: (test=0.736) total time=   3.0s
# [CV 1/5] END bootstrap=False, max_depth=60, max_features=0.8, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; neg_mean_squared_error: (test=-2.674) r2: (test=0.730) total time=  12.3s
# [CV 2/5] END bootstrap=False, max_depth=60, max_features=0.8, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; neg_mean_squared_error: (test=-2.740) r2: (test=0.718) total time=  12.5s
# [CV 3/5] END bootstrap=False, max_depth=60, max_features=0.8, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; neg_mean_squared_error: (test=-2.751) r2: (test=0.719) total time=  13.7s
# [CV 4/5] END bootstrap=False, max_depth=60, max_features=0.8, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; neg_mean_squared_error: (test=-2.804) r2: (test=0.714) total time=  14.3s
# [CV 5/5] END bootstrap=False, max_depth=60, max_features=0.8, min_samples_leaf=10, min_samples_split=5, n_estimators=1000; neg_mean_squared_error: (test=-2.624) r2: (test=0.726) total time=  14.1s
# [CV 1/5] END bootstrap=True, max_depth=80, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=366; neg_mean_squared_error: (test=-2.565) r2: (test=0.741) total time=   3.9s
# [CV 2/5] END bootstrap=True, max_depth=80, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=366; neg_mean_squared_error: (test=-2.644) r2: (test=0.728) total time=   3.9s
# [CV 3/5] END bootstrap=True, max_depth=80, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=366; neg_mean_squared_error: (test=-2.654) r2: (test=0.728) total time=   3.5s
# [CV 4/5] END bootstrap=True, max_depth=80, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=366; neg_mean_squared_error: (test=-2.712) r2: (test=0.723) total time=   3.6s
# [CV 5/5] END bootstrap=True, max_depth=80, max_features=0.5, min_samples_leaf=1, min_samples_split=5, n_estimators=366; neg_mean_squared_error: (test=-2.527) r2: (test=0.736) total time=   3.5s
# [CV 1/5] END bootstrap=False, max_depth=170, max_features=log2, min_samples_leaf=8, min_samples_split=20, n_estimators=50; neg_mean_squared_error: (test=-2.675) r2: (test=0.729) total time=   0.3s
# [CV 2/5] END bootstrap=False, max_depth=170, max_features=log2, min_samples_leaf=8, min_samples_split=20, n_estimators=50; neg_mean_squared_error: (test=-2.719) r2: (test=0.721) total time=   0.3s
# [CV 3/5] END bootstrap=False, max_depth=170, max_features=log2, min_samples_leaf=8, min_samples_split=20, n_estimators=50; neg_mean_squared_error: (test=-2.722) r2: (test=0.721) total time=   0.2s
# [CV 4/5] END bootstrap=False, max_depth=170, max_features=log2, min_samples_leaf=8, min_samples_split=20, n_estimators=50; neg_mean_squared_error: (test=-2.764) r2: (test=0.718) total time=   0.3s
# [CV 5/5] END bootstrap=False, max_depth=170, max_features=log2, min_samples_leaf=8, min_samples_split=20, n_estimators=50; neg_mean_squared_error: (test=-2.586) r2: (test=0.730) total time=   0.3s
# [CV 1/5] END bootstrap=True, max_depth=100, max_features=0.8, min_samples_leaf=8, min_samples_split=5, n_estimators=50; neg_mean_squared_error: (test=-2.608) r2: (test=0.736) total time=   0.6s
# [CV 2/5] END bootstrap=True, max_depth=100, max_features=0.8, min_samples_leaf=8, min_samples_split=5, n_estimators=50; neg_mean_squared_error: (test=-2.686) r2: (test=0.724) total time=   0.6s
# [CV 3/5] END bootstrap=True, max_depth=100, max_features=0.8, min_samples_leaf=8, min_samples_split=5, n_estimators=50; neg_mean_squared_error: (test=-2.673) r2: (test=0.726) total time=   0.5s
# [CV 4/5] END bootstrap=True, max_depth=100, max_features=0.8, min_samples_leaf=8, min_samples_split=5, n_estimators=50; neg_mean_squared_error: (test=-2.745) r2: (test=0.720) total time=   0.5s
# [CV 5/5] END bootstrap=True, max_depth=100, max_features=0.8, min_samples_leaf=8, min_samples_split=5, n_estimators=50; neg_mean_squared_error: (test=-2.536) r2: (test=0.735) total time=   0.6s
# [CV 1/5] END bootstrap=False, max_depth=150, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=155; neg_mean_squared_error: (test=-2.577) r2: (test=0.739) total time=   0.8s
# [CV 2/5] END bootstrap=False, max_depth=150, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=155; neg_mean_squared_error: (test=-2.660) r2: (test=0.727) total time=   0.8s
# [CV 3/5] END bootstrap=False, max_depth=150, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=155; neg_mean_squared_error: (test=-2.637) r2: (test=0.730) total time=   0.8s
# [CV 4/5] END bootstrap=False, max_depth=150, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=155; neg_mean_squared_error: (test=-2.702) r2: (test=0.724) total time=   0.8s
# [CV 5/5] END bootstrap=False, max_depth=150, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=155; neg_mean_squared_error: (test=-2.503) r2: (test=0.738) total time=   0.9s
# [CV 1/5] END bootstrap=True, max_depth=140, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=788; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=140, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=788; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=140, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=788; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=140, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=788; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 5/5] END bootstrap=True, max_depth=140, max_features=auto, min_samples_leaf=10, min_samples_split=5, n_estimators=788; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 1/5] END bootstrap=False, max_depth=130, max_features=0.5, min_samples_leaf=8, min_samples_split=2, n_estimators=50; neg_mean_squared_error: (test=-2.608) r2: (test=0.736) total time=   0.5s
# [CV 2/5] END bootstrap=False, max_depth=130, max_features=0.5, min_samples_leaf=8, min_samples_split=2, n_estimators=50; neg_mean_squared_error: (test=-2.682) r2: (test=0.724) total time=   0.6s
# [CV 3/5] END bootstrap=False, max_depth=130, max_features=0.5, min_samples_leaf=8, min_samples_split=2, n_estimators=50; neg_mean_squared_error: (test=-2.667) r2: (test=0.727) total time=   0.6s
# [CV 4/5] END bootstrap=False, max_depth=130, max_features=0.5, min_samples_leaf=8, min_samples_split=2, n_estimators=50; neg_mean_squared_error: (test=-2.730) r2: (test=0.721) total time=   0.6s
# [CV 5/5] END bootstrap=False, max_depth=130, max_features=0.5, min_samples_leaf=8, min_samples_split=2, n_estimators=50; neg_mean_squared_error: (test=-2.552) r2: (test=0.733) total time=   0.6s
# [CV 1/5] END bootstrap=True, max_depth=180, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1000; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 2/5] END bootstrap=True, max_depth=180, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1000; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 3/5] END bootstrap=True, max_depth=180, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1000; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# [CV 4/5] END bootstrap=True, max_depth=180, max_features=auto, min_samples_leaf=8, min_samples_split=2, n_estimators=1000; neg_mean_squared_error: (test=nan) r2: (test=nan) total time=   0.0s
# ...
# [CV 5/5] END bootstrap=True, max_depth=90, max_features=0.8, min_samples_leaf=8, min_samples_split=20, n_estimators=472; neg_mean_squared_error: (test=-2.536) r2: (test=0.735) total time=   4.6s
#            R2       MSE  n_estimators max_features max_depth  \
# 434  0.734716 -2.586794           683          0.5        50
# 122  0.734545 -2.588470          1000         log2        50
# 251  0.734413 -2.589722           472          0.5       220
# 65   0.734378 -2.590042          1000          0.5        90
# 52   0.734296 -2.590893           577         sqrt      None
# ..        ...       ...           ...          ...       ...
# 200       NaN       NaN            50         auto       120
# 204       NaN       NaN           155         auto      None
# 373       NaN       NaN           683         auto        60
# 219       NaN       NaN           788         auto        10
# 249       NaN       NaN           366         auto       140
#
#      min_samples_split  min_samples_leaf  bootstrap  rank R2  rank MSE
# 434                 15                 1       True        1         1
# 122                 15                 1      False        2         2
# 251                 10                 1       True        3         3
# 65                  10                 2       True        4         4
# 52                  10                 1       True        5         5
# ..                 ...               ...        ...      ...       ...
# 200                  5                 4      False      407       407
# 204                 15                 1       True      407       407
# 373                 20                 2       True      407       407
# 219                 10                 8       True      407       407
# 249                 10                 4      False      407       407
#
# [500 rows x 10 columns]
# /home/niklaska/.virtualenvs/r-virtualenv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 470 fits failed out of a total of 2500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 470 fits failed with the following error:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_110656/222628487.py", line 2, in <module>
#     with open('../pickles/rf_random_search_tuning_results.pickle', 'rb') as handle:
#   File "/home/niklaska/.virtualenvs/r-virtualenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 324, in _modified_open
#     return io_open(file, *args, **kwargs)
# FileNotFoundError: [Errno 2] No such file or directory: '../pickles/rf_random_search_tuning_results.pickle'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/niklaska/.virtualenvs/r-virtualenv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/niklaska/.virtualenvs/r-virtualenv/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/home/niklaska/.virtualenvs/r-virtualenv/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/home/niklaska/.virtualenvs/r-virtualenv/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/niklaska/.virtualenvs/r-virtualenv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [0.72125484        nan 0.72886032        nan 0.73189567 0.72714669
#  0.71739186 0.72131087        nan 0.73372812 0.72823853 0.7114379
#  0.72976727        nan 0.73378556 0.72335167 0.72951712 0.73195906
#  0.73353517 0.72572505        nan        nan        nan 0.73354277
#  0.72833888 0.72823826 0.73006534 0.72301809 0.72637175        nan
#  0.73207647 0.7297466  0.72336738 0.73405263 0.72014991 0.72580881
#  0.72982335        nan 0.72560297 0.73275559 0.73064566 0.72119022
#  0.73125367 0.72380351 0.72827676 0.73172512        nan 0.72846624
#         nan 0.72912492        nan 0.7329231  0.73429635 0.71688295
#         nan 0.72914487 0.72661635        nan 0.73172839 0.72431164
#         nan 0.73024445 0.72695286 0.71831719 0.71701189 0.73437825
#  0.73265401 0.72868418 0.72768013 0.71672266 0.7341445  0.71722993
#  0.72352798 0.71999506 0.71679967 0.72787319 0.7287072  0.72323119
#  0.72983536 0.7062083  0.71991599 0.72265269        nan 0.72572155
#         nan        nan 0.72812625 0.71711564 0.72702419 0.72805025
#  0.73264157        nan 0.72925621 0.73248323 0.72626468 0.72934377
#  0.71708906 0.73012104 0.73374975 0.72837621 0.72800576 0.73236626
#  0.73378188 0.72843342        nan 0.72972751        nan 0.71342122
#  0.72817507 0.72293822 0.72903088 0.72582925 0.7202957  0.72960506
#         nan 0.71895792 0.73041964        nan 0.73079781 0.73189945
#  0.71273957        nan 0.73454505        nan 0.72909458 0.72852927
#  0.7271678  0.72207792 0.72961116        nan 0.72909259 0.72681097
#  0.72015355 0.72977853 0.7052552  0.72933592 0.7243283  0.72061671
#  0.72083295 0.72880214        nan 0.72691867 0.72066787 0.73045796
#  0.72881342 0.72759814 0.73194871 0.7341375  0.70524275 0.73399733
#  0.7283458  0.7302612  0.72387684 0.73032566        nan        nan
#  0.73064843 0.71667034 0.73155894 0.7027925  0.71711165        nan
#  0.72586488 0.72333617 0.72974015        nan        nan        nan
#  0.73024893 0.71715999 0.7295151  0.73069978 0.72115166 0.7286117
#  0.71697482 0.72062723 0.72339207 0.73207781        nan 0.72994679
#  0.72696863 0.73032414 0.72622201 0.72626468 0.71854877 0.72934211
#  -2.75891132 -2.89076824 -2.67254689 -2.61829275         nan -2.59757133
#  -2.7579489  -2.64118746 -2.87937105 -2.62190032 -2.72911362 -2.71847696
#  -2.6608826  -2.64726085         nan -2.67523374 -2.69792597 -2.72159757
#  -3.00192803 -2.62608944 -2.75938518 -2.63767562 -2.62974548         nan
#  -2.75782904 -2.72515322         nan -2.69668521 -2.63023509 -2.63503715
#  -2.73082153 -2.66041266 -2.62933476 -2.72340261         nan -2.59681717
#  -2.67334556 -2.69652951 -2.66912026 -2.63853562 -2.77947796 -2.71874329
#          nan -2.76701961         nan -2.59992408 -2.67192899 -2.75798097
#          nan -2.61702399 -2.7537388  -2.61872223 -2.63883753 -2.70575227
#          nan -2.63706793]
#   warnings.warn(

# %%
print(rf_random_search_tuning_results.sort_values('rank R2'))
# Out:
#            R2       MSE  n_estimators max_features max_depth  \
# 434  0.734716 -2.586794           683          0.5        50
# 122  0.734545 -2.588470          1000         log2        50
# 251  0.734413 -2.589722           472          0.5       220
# 65   0.734378 -2.590042          1000          0.5        90
# 52   0.734296 -2.590893           577         sqrt      None
# ..        ...       ...           ...          ...       ...
# 200       NaN       NaN            50         auto       120
# 204       NaN       NaN           155         auto      None
# 373       NaN       NaN           683         auto        60
# 219       NaN       NaN           788         auto        10
# 249       NaN       NaN           366         auto       140
#
#      min_samples_split  min_samples_leaf  bootstrap  rank R2  rank MSE
# 434                 15                 1       True        1         1
# 122                 15                 1      False        2         2
# 251                 10                 1       True        3         3
# 65                  10                 2       True        4         4
# 52                  10                 1       True        5         5
# ..                 ...               ...        ...      ...       ...
# 200                  5                 4      False      407       407
# 204                 15                 1       True      407       407
# 373                 20                 2       True      407       407
# 219                 10                 8       True      407       407
# 249                 10                 4      False      407       407
#
# [500 rows x 10 columns]

# %%
try:
    with open('../pickles/rf_grid_search_tuning_results.pickle', 'rb') as handle:
        rf_grid_search_results = pickle.load(handle)
except:
    params = {
        'n_estimators': [int(x) for x in np.linspace(start=650, stop=700, num=5)],
        'max_features': [0.5],
        'max_depth': [int(x) for x in np.linspace(45, 55, num=1)],
        'min_samples_split': [14, 15, 16],
        'min_samples_leaf': [1, 2, 3],
        'bootstrap': [True]
    }

    g_search = GridSearchCV(RandomForestRegressor(n_jobs=-1), params, scoring=['r2', 'neg_mean_squared_error'], verbose=3, refit=False)
    g_search.fit(train_x, train_y)
    rf_grid_search_results = g_search.cv_results_

rf_grid_search_tuning_results = pd.DataFrame({
    'R2': rf_random_search_results['mean_test_r2'],
    'MSE': rf_random_search_results['mean_test_neg_mean_squared_error'],
    'n_estimators': rf_random_search_results['param_n_estimators'],
    'max_features': rf_random_search_results['param_max_features'],
    'max_depth': rf_random_search_results['param_max_depth'],
    'min_samples_split': rf_random_search_results['param_min_samples_split'],
    'min_samples_leaf': rf_random_search_results['param_min_samples_leaf'],
    'bootstrap' : rf_random_search_results['param_bootstrap'],
    'rank R2': rf_random_search_results['rank_test_r2'],
    'rank MSE': rf_random_search_results['rank_test_neg_mean_squared_error'],
})
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# [CV 1/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=1, min_samples_split=14, n_estimators=650; neg_mean_squared_error: (test=-2.531) r2: (test=0.744) total time=   4.9s
# [CV 2/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=1, min_samples_split=14, n_estimators=650; neg_mean_squared_error: (test=-2.622) r2: (test=0.730) total time=   4.8s
# [CV 3/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=1, min_samples_split=14, n_estimators=650; neg_mean_squared_error: (test=-2.611) r2: (test=0.733) total time=   4.7s
# [CV 4/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=1, min_samples_split=14, n_estimators=650; neg_mean_squared_error: (test=-2

# [CV 5/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=3, min_samples_split=16, n_estimators=675; neg_mean_squared_error: (test=-2.492) r2: (test=0.740) total time=   5.3s
# [CV 1/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=3, min_samples_split=16, n_estimators=687; neg_mean_squared_error: (test=-2.548) r2: (test=0.742) total time=   5.5s
# [CV 2/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=3, min_samples_split=16, n_estimators=687; neg_mean_squared_error: (test=-2.635) r2: (test=0.729) total time=   5.4s
# [CV 3/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=3, min_samples_split=16, n_estimators=687; neg_mean_squared_error: (test=-2.611) r2: (test=0.733) total time=   5.5s
# [CV 4/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=3, min_samples_split=16, n_estimators=687; neg_mean_squared_error: (test=-2.689) r2: (test=0.726) total time=   5.5s
# [CV 5/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=3, min_samples_split=16, n_estimators=687; neg_mean_squared_error: (test=-2.490) r2: (test=0.740) total time=   5.5s
# [CV 1/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=3, min_samples_split=16, n_estimators=700; neg_mean_squared_error: (test=-2.553) r2: (test=0.742) total time=   5.5s
# [CV 2/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=3, min_samples_split=16, n_estimators=700; neg_mean_squared_error: (test=-2.635) r2: (test=0.729) total time=   5.6s
# [CV 3/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=3, min_samples_split=16, n_estimators=700; neg_mean_squared_error: (test=-2.609) r2: (test=0.733) total time=   5.0s
# [CV 4/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=3, min_samples_split=16, n_estimators=700; neg_mean_squared_error: (test=-2.685) r2: (test=0.726) total time=   4.9s
# [CV 5/5] END bootstrap=True, max_depth=45, max_features=0.5, min_samples_leaf=3, min_samples_split=16, n_estimators=700; neg_mean_squared_error: (test=-2.489) r2: (test=0.740) total time=   4.8s
#            R2       MSE  n_estimators max_features max_depth  \
# 434  0.734716 -2.586794           683          0.5        50
# 122  0.734545 -2.588470          1000         log2        50
# 251  0.734413 -2.589722           472          0.5       220
# 65   0.734378 -2.590042          1000          0.5        90
# 52   0.734296 -2.590893           577         sqrt      None
# ..        ...       ...           ...          ...       ...
# 200       NaN       NaN            50         auto       120
# 204       NaN       NaN           155         auto      None
# 373       NaN       NaN           683         auto        60
# 219       NaN       NaN           788         auto        10
# 249       NaN       NaN           366         auto       140
#
#      min_samples_split  min_samples_leaf  bootstrap  rank R2  rank MSE
# 434                 15                 1       True        1         1
# 122                 15                 1      False        2         2
# 251                 10                 1       True        3         3
# 65                  10                 2       True        4         4
# 52                  10                 1       True        5         5
# ..                 ...               ...        ...      ...       ...
# 200                  5                 4      False      407       407
# 204                 15                 1       True      407       407
# 373                 20                 2       True      407       407
# 219                 10                 8       True      407       407
# 249                 10                 4      False      407       407
#
# [500 rows x 10 columns]
# /home/niklaska/.virtualenvs/r-virtualenv/lib/python3.10/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
print(rf_grid_search_tuning_results.sort_values('rank R2'))
# Out:
#            R2       MSE  n_estimators max_features max_depth  \
# 434  0.734716 -2.586794           683          0.5        50
# 122  0.734545 -2.588470          1000         log2        50
# 251  0.734413 -2.589722           472          0.5       220
# 65   0.734378 -2.590042          1000          0.5        90
# 52   0.734296 -2.590893           577         sqrt      None
# ..        ...       ...           ...          ...       ...
# 200       NaN       NaN            50         auto       120
# 204       NaN       NaN           155         auto      None
# 373       NaN       NaN           683         auto        60
# 219       NaN       NaN           788         auto        10
# 249       NaN       NaN           366         auto       140
#
#      min_samples_split  min_samples_leaf  bootstrap  rank R2  rank MSE
# 434                 15                 1       True        1         1
# 122                 15                 1      False        2         2
# 251                 10                 1       True        3         3
# 65                  10                 2       True        4         4
# 52                  10                 1       True        5         5
# ..                 ...               ...        ...      ...       ...
# 200                  5                 4      False      407       407
# 204                 15                 1       True      407       407
# 373                 20                 2       True      407       407
# 219                 10                 8       True      407       407
# 249                 10                 4      False      407       407
#
# [500 rows x 10 columns]

# %% [markdown]
# ## Pickle

# %%
with open('../pickles/rf_random_search_tuning_results.pickle', 'wb+') as handle:
    pickle.dump(r_search.cv_results_, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('../pickles/rf_grid_search_tuning_results.pickle', 'wb+') as handle:
    pickle.dump(g_search.cv_results_, handle, protocol=pickle.HIGHEST_PROTOCOL)
